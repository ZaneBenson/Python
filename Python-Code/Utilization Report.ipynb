# %%
import pandas as pd

# Read the excel sheet to pandas dataframe
df = pd.read_excel(r"U:\Finance\Utilization\UTILIZATION-2019\June Utilization Data.xlsx", sheetname=0)
df = df.drop(['Entry Type',
              'Job No.',
              'Job WBS Code',
             'Labor Category Code',
             'Department Code Dimension',
             'Item No.',
             'Unit Cost',
             'Unit Cost ($)',
             'Total Cost',
             'Total Cost ($)',
             'Unit Price',
             'Line Amount',
             'Line Discount Amount',
             'Line Discount %',
             'Revenue Amount',
             'Ledger Entry Type',
             'Ledger Entry No.',
             'Entry No.',
             'Adjusted',
             'DateTime Adjusted',
             'Posting Account No.'], axis = 1)

# %%
df.sort_values(by=['Posting Date','Type'], inplace = True)

# %%
print(df)
# Out:
#      Posting Date Document No.        Job Task No.         Type     No.  \
# 2084   2019-05-01    PINV-0094            4195-026  G/L Account   55100
# 2083   2019-05-01    PINV-0094            4195-026  G/L Account   55100
# 2082   2019-05-01    PINV-0095            4195-022  G/L Account   55100
# 2081   2019-05-01    PINV-0095            4195-022  G/L Account   55100
# 2080   2019-05-01    PINV-0096            4195-025  G/L Account   55100
# 2079   2019-05-01    PINV-0096            4195-025  G/L Account   55100
# 2078   2019-05-01    PINV-0097            4195-028  G/L Account   55100
# 2077   2019-05-01    PINV-0097            4195-028  G/L Account   55100
# 2076   2019-05-01    PINV-0098            4195-021  G/L Account   55100
# 1585   2019-05-01    PINV-0137            4723-001  G/L Account   54100
# 1586   2019-05-01    PINV-0137            4723-001  G/L Account   54100
# 2075   2019-05-01    PINV-0099            4195-021  G/L Account   55100
# ...
